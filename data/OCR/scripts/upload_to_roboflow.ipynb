# %%
# !source .venv/bin/activate
# Out:
# zsh:source:1: no such file or directory: .venv/bin/activate

# %%
# Install
# !pip install roboflow

# %%
# Authenticate
# !roboflow login
# Importfa2f7301-394b-40c5-aed1-f38eb26b4754
# Out:
# visit https://app.roboflow.com/auth-cli to get your authentication token.
# Paste the authentication token here: Traceback (most recent call last):
#   File "/Users/marcelmerkx/Development/container-digit-detector/.venv311/bin/roboflow", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/Users/marcelmerkx/Development/container-digit-detector/.venv311/lib/python3.11/site-packages/roboflow/roboflowpy.py", line 571, in main
#     args.func(args)
#   File "/Users/marcelmerkx/Development/container-digit-detector/.venv311/lib/python3.11/site-packages/roboflow/roboflowpy.py", line 19, in login
#     roboflow.login(force=args.force)
#   File "/Users/marcelmerkx/Development/container-digit-detector/.venv311/lib/python3.11/site-packages/roboflow/__init__.py", line 86, in login
#     token = getpass("Paste the authentication token here: ")
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# !roboflow import -w cargosnap -p unified-detection-0zmvz /Users/marcelmerkx/Development/container-digit-detector/data/dataset/images/cutouts
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# 100%|██████████████████████████████████| 1031/1031 [00:00<00:00, 3318747.06it/s]
# Uploading to existing project cargosnap/unified-detection-0zmvz
# [DUPLICATE] /Users/marcelmerkx/Development/container-digit-detector/data/dataset/images/cutouts/BEAU5300780.jpg (alIyX3583BUrE4Aa1Oib) [0.6s]
# [DUPLICATE] /Users/marcelmerkx/Development/container-digit-detector/data/dataset/images/cutouts/BEAU5859146.jpg (Gk9yqYZf1dAXco3tWdRt) [0.6s]
# [DUPLICATE] /Users/marcelmerkx/Development/container-digit-detector/data/dataset/images/cutouts/BEAU6075339.jpg (peLTPvqDSoT13R1ZRL6R) [0.7s]
# [DUPLICATE] /Users/marcelmerkx/Development/container-digit-detector/data/dataset/images/cutouts/ACLU9806341.jpg (EvzNDwmtLH76ls5pJzjA) [0.7s]
# [DUPLICATE] /Users/marcelmerkx/Development/container-digit-detector/data/dataset/images/cutouts/BEAU5995800.jpg (7yb24NOiOv3fojgao9Kc) [0.7s]
# ...
